# %% [markdown]
# <a href="https://colab.research.google.com/github/miftaahhidayat21/Pemerograman-Dasar/blob/main/pertemuan%20kedua.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Latihan 1

tegangan = 18
arus = 6
jenis_sel = "Monocrystalline"

print(tegangan)
print(arus)
print(jenis_sel)

# Jawaban Latihan 2

jumlah_komponen = 10
tegangan = 220.5
mesin_aktif = True
nama_komponen = "Motor"

print(jumlah_komponen)
print(type(jumlah_komponen))

print(tegangan)
print(type(tegangan))

print(mesin_aktif)
print(type(mesin_aktif))

print(nama_komponen)
print(type(nama_komponen))

# Jawaban Latihan 3

nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = True

print(nama_unit)
print(type(nama_unit))

print(jumlah_panel)
print(type(jumlah_panel))

print(tegangan_keluaran)
print(type(tegangan_keluaran))

print(sedang_beroperasi)
print(type(sedang_beroperasi))

# Jawaban Latihan 4

tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

# Data pertama
print("Pembacaan pertama:", tegangan_harian[0])

# Data terakhir
print("Pembacaan terakhir:", tegangan_harian[-1])

# Menambahkan data baru
tegangan_harian.append(222.0)

# Menampilkan jumlah total data
print("Jumlah total data:", len(tegangan_harian))

# Jawaban Latihan 5

motor = { "nama": "Motor Listrik",
    "daya_kW": 5.5,
    "tegangan_V": 220,
    "rpm": 1500}

# Mencetak salah satu nilai
print("Nama motor:", motor["nama"])

# Mengubah nilai rpm
motor["rpm"] = 1800

# Mencetak seluruh dictionary
print(motor)

# Jawaban Latihan 6

pembangkit = [{"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80, "status": "pemeliharaan"}]

# Mencetak nama unit kedua
print("Nama unit kedua:", pembangkit[1]["nama"])

# Mengubah status Unit-3
pembangkit[2]["status"] = "operasi"

# Menambahkan unit baru
pembangkit.append(
    {"nama": "Unit-4", "kapasitas_MW": 120, "status": "operasi"}
)

# Mencetak seluruh data
print(pembangkit)
# Out:
# 18
# 6
# Monocrystalline
# 10
# <class 'int'>
# 220.5
# <class 'float'>
# True
# <class 'bool'>
# Motor
# <class 'str'>
# PLTS Nunukan
# <class 'str'>
# 240
# <class 'int'>
# 48.5
# <class 'float'>
# True
# <class 'bool'>
# Pembacaan pertama: 217.5
# Pembacaan terakhir: 216.9
# Jumlah total data: 7
# Nama motor: Motor Listrik
# {'nama': 'Motor Listrik', 'daya_kW': 5.5, 'tegangan_V': 220, 'rpm': 1800}
# Nama unit kedua: Unit-2
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'operasi'}, {'nama': 'Unit-4', 'kapasitas_MW': 120, 'status': 'operasi'}]
