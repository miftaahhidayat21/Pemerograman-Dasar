# %% [markdown]
# <a href="https://colab.research.google.com/github/miftaahhidayat21/Pemerograman-Dasar/blob/main/Pertemuan_1_kelas_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Biodata saya

nama = "miftaah"
umur = 19
jurusan = "TRPE"
semester = 3
Matakuliah = "pemerograman dasar"
status_lulus= True

print (nama)
print (umur)
print (jurusan)
print (semester)
print (Matakuliah)
print (status_lulus)
# Out:
# miftaah
# 19
# TRPE
# 3
# pemerograman dasar
# True
